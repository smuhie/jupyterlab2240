# %% [markdown]
# # INTRODUCTION TO PYTHON

# %% [markdown]
# ### 2023FA-INT-2240-RE02 Intro to Python

# %% [markdown]
# #     Module 1: Basics of Programming Languages

# %% [markdown]
# ## 1.1 Computational thinking

# %% [markdown]
# ### Computational Thinking
# To write the real piece of code, first learn the skill of breaking problems down into achievable little actions that a computer can do for you
#
#
# ![image.png](attachment:image.png)
# image.pngsource: https://www.wcpss.net/domain/17003
#
# ## Computational Thinking
# Computational Thinking is an approach to problem solving with four key thinking processes;
#
# __decomposition__- taking ideas and problems apart,
#
# __pattern recognition__- looking for similarities or trends,
#
# __abstraction__- focusing on what’s most important, and
#
# __algorithm design__- creating step-by-step instructions to solve a problem.
#
# Introducing these skills and providing time to practice them in all subject areas allows students to build their confidence as innovative problem solvers. Students begin to recognize the use of these skills in reading, math, science, social studies and even the everyday structures of the school day. They practice communicating their ideas clearly through the lens of these processes so that others can understand their thinking and collaborate with them.
#
# ![image-2.png](attachment:image-2.png)
# image.pngsource: https://robbotresources.com/blog/2018/11/3/what-is-computational-thinking
#
# Decomposition involves breaking the problem down into smaller components. The more you can break a problem down, the easier it is to solve.
#
# __Decomposition__ is breaking down a complex idea or subject into smaller component parts.
#
# __Pattern Recognition__ whereby similarities and trends are identified within the problem. If some problems are similar in nature (both within the current problem being tackled or within past problems), there is a good chance that they can be solved using similar, or repeated techniques. This is a key component for making efficient solutions, and saving you time in the long run. Consider a scenario where you are asked to write a short programme to draw a square. The pattern of drawing a line and rotating the pen 90 degrees can be repeated 4 times in a loop rather than writing out the instruction four times in a row. Pattern Recognition is a key skill when it comes to creating efficient and effective solutions to given problems.
#
# Observing and analyzing data, situations, or a series of events to understand repeating elements or series of elements.
# __Abstraction__ involves the identification of key components of the solution. Rather than looking at specific details, it requires the ability to filter out unnecessary elements of a problem so that you only focus on the important elements. Prior to creating a building, an architect may want to present their design as a scaled down model. This model will include all the key design elements that will be included within the final building.
#
# __Abstraction__ is the ability to gain universally true insights from a specific example. This happens by removing unnecessary information or material until core insights can be discovered.
#
# __Algorithm Design__ whereby a detailed step-by-step set of instructions are created which explain how to solve the problem. The measure of a good algorithm is one that can be passed to someone else to follow without the need for any extra explanation. As an additional component attached to the algorithm design phase, debugging is also an important skill to develop.
#
# Explicit series of steps and procedures that can be followed with reproducible results.
#
# __Debugging__ refers to the ability to identify and rectify errors within an algorithm. As with the other components of Computational Thinking, debugging is a transferrable skill and can be developed across the curriculum through acting upon and providing feedback. Algorithms help us to make sense of the World around us.

# %% [markdown]
# ### write a program which can used to operate our fishing robot

# %% [markdown]
# 1. tie the hook on the fishing line
# 2. put a bate on it
# 3. cast it (in the water)
# 4. wait until feeling of a pull
# 5. reel in really slowly
# 6. unhook the fish
# 7. do it again
# 8. if not pulling within 10 minutes reel in again
# 10. recast into the water

# %%
print(50)
# Out:
# 50

# %%
print(good!)
# Out:
#   Input In [15]
#     print(good!)
#               ^
# SyntaxError: invalid syntax

# %%
print('welcome!')
# Out:
# welcome!

# %%
good = 'this is a welcome message'

# %%
print(good)
# Out:
# this is a welcome message

# %%
print(market)
# Out:
# Neyork Stock Market

# %%
market = 'Neyork Stock Market'

# %%
my_favorite = "Python's syntax"

# %%
print(my_favorite)
# Out:
# Python's syntax

# %%
int("50")
# Out:
# 50

# %%
type(my_favorite)
# Out:
# str

# %%
type('50')
# Out:
# str

# %%
type(int('50'))
# Out:
# int

# %%
print(type(int(50)))
# Out:
# <class 'int'>

# %% [markdown]
# Summary points
# 1. print: output on screen
# 2. int: to convert to an integer
# 3. float to convert to a decimal number
# 4. type: find out the data type
# 5. = is assigment
# 6. == equal sign

# %%
float('6')
# Out:
# 6.0

# %%
my_favorite = 'python'

# %%
print(my_favorite)
# Out:
# python

# %% [markdown]
# ### A computer program for a fishing robot
#
# One thing to understand right up front is that computers do exactly what you tell them — nothing more, nothing less. Look at our recipe for fishing in “Breaking it down”. If you were the robot and you followed these instructions precisely, what problems might you encounter? Do you think we would really be successful using this recipe?

# %% [markdown]
#     break the activity of fishing down into a simple set of instructions that you could hand to a robot, who would do your fishing for you

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __Algorithm__ a sequence of instructions that solves some problem. Algorithms are first written in an informal form of code called __pseudocode__

# %% [markdown]
# ## How coding works?
# #### the steps to write code:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### program development cycle
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The process of writing and testing code can be error-prone
#     If Python reported an error like
#
#     invalid syntax
#     Python NameError: name ‘prin’ is not defined
#     EOL while scanning that typically means you left out a single quote on one of the (EOL -- End Of Line)

# %%
print("hello world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 pritn("hello world")
#
# NameError: name 'pritn' is not defined

# %% [markdown]
# ### Summary
# * Computational thinking is a way of thinking about problem solving.
# * Coding is the act of taking an algorithm and translating its steps into a programming language that can be executed on a computer.
# * To write code, you first have to break a problem down into a simple set of actions that solves the problem.
# * We call this set of actions an algorithm, or less formally a recipe for solving a problem.
# * Actions are in the form of statements that can carry out very simple tasks, make decisions, or control the flow of an algorithm by repeating parts of the code.
# * Algorithms are sometimes expressed in a more human-readable pseudocode before being translated to an actual programming language.
# * Programming languages are special-purpose languages created expressly for describing tasks to computers.
# * English makes for a poor programming language because it is quite ambiguous.
# * There are many programming languages, each created with inherent advantages and disadvantages, but all have the same computational power.
# * The Python name doesn’t come from a snake, but from the creator’s love of the Monty Python comedy troupe.
# * New and experienced programmers appreciate Python’s clean and consistent design.
# * There are two versions of Python, 2 and 3, and this book focuses on Python 3 (although the differences are minor in a lot of cases).
# * Python code is executed by an interpreter, which translates high-level Python code into low-level machine code that your computer can execute directly.
# * Python provides an editor called IDLE that is tailored to writing Python code.
# * You can use whitespace in a Python program to increase readability.
# * input and print are two functions provided by Python for simple, shell-based input and output.

# %%
class_name = "The course number of this class"

# %%
print(class_name)
# Out:
# The course number of this class

# %%
type(class_name)
# Out:
# str

# %%
2240_pyhon = "my favorite course"
# Out:
#   Input In [36]
#     2240_pyhon = "my favorite course"
#         ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## Variable naming rules
# * variable names should not start with numbers
# * we shouldn't use python key words: class, print, int, float, input etc
# * variable names cannot include space
# * The first character must be one of the letters a through z, A through Z, or an underscore character (_).
# * After the first character you may use the letters a through z or A through Z, the digits 0 through 9, or underscores.

# %%
python_2240 = "my favorite course"

# %%
print(python_2240)
# Out:
# my favorite course

# %%
python 2240 = "my favorite course"
# Out:
#   Input In [39]
#     python 2240 = "my favorite course"
#            ^
# SyntaxError: invalid syntax

# %%
_python = "my favorite programming language"

# %%
type(5.0)
# Out:
# float

# %%
my_name = input('what is your first name') # prompting the user (asking something from the user)
# Out:
# what is your first nameseid

# %%
print(myname)
# Out:
# seid

# %%
my_age = int(input('your age please')) # the return from an input function is a string
# Out:
# your age please50

# %%
print(myage)
# Out:
# 50

# %%
type(myage)
# Out:
# int

# %% [markdown]
# The cat said 'meow'

# %%
print("The cat said 'meow'")
# Out:
# The cat said 'meow'

# %%
first_name = input('your first name please')
# Out:
# your first name pleaseseid

# %%
last_name = input('please provide your name')
# Out:
# please provide your namemuhie

# %%
print("hello",first_name,last_name)
# Out:
# hello seid muhie

# %%
first_nummber = int(input('give me your first number'))
# Out:
# give me your first number100

# %%
print((100+100+100)//3)
# Out:
# 100

# %% [markdown]
# ## Operators
#     * (multiplication)
#     / or // (division)
#     + (additon)
#     - (subtraction)
#     ** (exponent)
#     % (modulus -- remainder)

# %%
23//7
# Out:
# 3

# %%
15/8
# Out:
# 1.875

# %%
15//8
# Out:
# 1

# %% [markdown]
# ### Operator Precedence!
#     ** exponent
#     * or / or // % (multiplication or division or modulus)
#     + or - addition or subtraction

# %%
25//5 + 3**2
# Out:
# 14

# %%
25//(5 + 3)**2
# Out:
# 0

# %%
25//(5 + 3**2)
# Out:
# 1

# %%
12 + 13 # + operator (for addition); 12 & 13 operands
# Out:
# 25

# %%
print('this is very long                                       statment.')
# Out:
# this is very long                                       statment.

# %%
print('my name is \\"seid muhie"')
# Out:
# my name is \"seid muhie"

# %%
print(format(12345.6789, ',.2f'))
# Out:
# 12,345.68

# %%
print(format(34578.932,',.1f'))
# Out:
# 34,578.9

# %%
student_ids_1 = [32, 75, 12, 28, 56, 91, 47] # data type is list; index for 56 4

# %%
type(student_ids_1)
# Out:
# list

# %%
student_ids_2 = (32, 75, 12, 28, 56, 91, 47) # data type is tuple (immutable)

# %%
type(student_ids_2)
# Out:
# tuple

# %% [markdown]
# ## Python data type
#     str "seid"
#     int  5
#     float 3.14
#     list [3, 2, 4]
#     tuple (2, 4,1)

# %%
my_id = ('james',)

# %%
type(my_id)
# Out:
# tuple

# %% [markdown]
# idex (indices)
# slicing (subsetting)
# append
# pop
